# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiomora03/AdvancedTopicsAnalytics/blob/main/exercises/E4-SpamClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 3
#
# ## Spam Classification
#
# ### Context
#
# The SMS Spam Collection is a set of SMS tagged messages that have been collected for SMS Spam research. It contains one set of SMS messages in English of 5,574 messages, tagged acording being ham (legitimate) or spam.
#
# ### Content
#
# The files contain one message per line. Each line is composed by two columns: v1 contains the label (ham or spam) and v2 contains the raw text.
#
# This corpus has been collected from free or free for research sources at the Internet:
#
# - A collection of 425 SMS spam messages was manually extracted from the Grumbletext Web site. This is a UK forum in which cell phone users make public claims about SMS spam messages, most of them without reporting the very spam message received. The identification of the text of spam messages in the claims is a very hard and time-consuming task, and it involved carefully scanning hundreds of web pages. The Grumbletext Web site is: [Web Link](http://www.grumbletext.co.uk/).
# - A subset of 3,375 SMS randomly chosen ham messages of the NUS SMS Corpus (NSC), which is a dataset of about 10,000 legitimate messages collected for research at the Department of Computer Science at the National University of Singapore. The messages largely originate from Singaporeans and mostly from students attending the University. These messages were collected from volunteers who were made aware that their contributions were going to be made publicly available. The NUS SMS Corpus is avalaible at: [Web Link](http://www.comp.nus.edu.sg/~rpnlpir/downloads/corpora/smsCorpus/).
# - A list of 450 SMS ham messages collected from Caroline Tag's PhD Thesis available at [Web Link](http://etheses.bham.ac.uk/253/1/Tagg09PhD.pdf).
# - Finally, we have incorporated the SMS Spam Corpus v.0.1 Big. It has 1,002 SMS ham messages and 322 spam messages and it is public available at: [Web Link](http://www.esp.uem.es/jmgomez/smsspamcorpus/). This corpus has been used in the following academic researches:
#
# Acknowledgements
# The original dataset can be found [here](https://archive.ics.uci.edu/ml/datasets/SMS+Spam+Collection). The creators would like to note that in case you find the dataset useful, please make a reference to previous paper and the web page: http://www.dt.fee.unicamp.br/~tiago/smsspamcollection/ in your papers, research, etc.
#
# We offer a comprehensive study of this corpus in the following paper. This work presents a number of statistics, studies and baseline results for several machine learning methods.
#
# Almeida, T.A., GÃ³mez Hidalgo, J.M., Yamakami, A. Contributions to the Study of SMS Spam Filtering: New Collection and Results. Proceedings of the 2011 ACM Symposium on Document Engineering (DOCENG'11), Mountain View, CA, USA, 2011.

# %%
# !pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=5f221a7871caeecd27b77de09b160f8d4d6fec8f0f4b62d75b01795985669f3e
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
import pandas as pd
import numpy as np
import wget
import os
from zipfile import ZipFile

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
import string

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    auc,
    roc_curve,
)

import gensim
from gensim.models import Word2Vec
import warnings


warnings.filterwarnings("ignore")
nltk.download("stopwords")
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
try :
    from google.colab import files
    # !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00228/smsspamcollection.zip
    # !unzip smsspamcollection.zip
    df = pd.read_csv('SMSSpamCollection', sep='\t',  header=None, names=['target', 'text'])
except ModuleNotFoundError :
    url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00228/smsspamcollection.zip'
    path = os.getcwd()+'\Data'
    wget.download(url,path)
    temp=path+'\smsspamcollection.zip'
    file = ZipFile(temp)
    file.extractall(path)
    file.close()
    df = pd.read_csv(path + '\SMSSpamCollection', sep='\t',  header=None, names=['target', 'text'])
# Out:
# --2023-09-11 17:47:46--  https://archive.ics.uci.edu/ml/machine-learning-databases/00228/smsspamcollection.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘smsspamcollection.zip’
#
# smsspamcollection.z     [  <=>               ] 198.65K   469KB/s    in 0.4s
#
# 2023-09-11 17:47:48 (469 KB/s) - ‘smsspamcollection.zip’ saved [203415]
#
# Archive:  smsspamcollection.zip
#   inflating: SMSSpamCollection
#   inflating: readme

# %%
df.head()
# Out:
#   target                                               text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
display(df.shape)  # Number of rows (instances) and columns in the dataset
df["target"].value_counts() / df.shape[0]  # Class distribution in the dataset
# Out:
# (5572, 2)
# ham     0.865937
# spam    0.134063
# Name: target, dtype: float64

# %%
X = df["text"]
y = df["target"].map({"ham": 0, "spam": 1})

# %%
# split data into training and validation set
X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=df["target"], test_size=0.3, random_state=18
)

# %% [markdown]
# Preprocess the text data by removing stop words, converting all text to lowercase, and removing punctuation using NLTK package.

# %%
stop_words = set(stopwords.words("english"))


def preprocess(text):
    text = text.lower()
    text = "".join([word for word in text if word not in string.punctuation])
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stop_words]
    return " ".join(tokens)


X_train = X_train.apply(preprocess)
X_test = X_test.apply(preprocess)

# %% [markdown]
# Train a Word2Vec model on the preprocessed training data using Gensim package.

# %%
sentences = [sentence.split() for sentence in X_train]
model = Word2Vec(
    sentences, vector_size=100, window=5, negative=20, min_count=1, workers=4
)

# %% [markdown]
# Convert the preprocessed text data to a vector representation using the Word2Vec model.

# %%
def vectorize(sentence):
    words = sentence.split()
    words_vecs = [model.wv[word] for word in words if word in model.wv]
    if len(words_vecs) == 0:
        return np.zeros(100)
    words_vecs = np.array(words_vecs)
    return words_vecs.mean(axis=0)


X_train = np.array([vectorize(sentence) for sentence in X_train])
X_test = np.array([vectorize(sentence) for sentence in X_test])

# %%
X_train
# Out:
# array([[-0.05393501,  0.20617983, -0.0501092 , ..., -0.29848632,
#          0.11499913, -0.03554979],
#        [-0.14267683,  0.50889486, -0.13371192, ..., -0.75160468,
#          0.2816619 , -0.09235888],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [-0.05059454,  0.19273016, -0.04789185, ..., -0.28034827,
#          0.10440069, -0.03411365],
#        [-0.14101665,  0.51574892, -0.1354534 , ..., -0.7640326 ,
#          0.28614825, -0.09694397],
#        [-0.17938885,  0.64317399, -0.16625655, ..., -0.95055997,
#          0.35330352, -0.11457501]])

# %% [markdown]
# Train a classification model such as logistic regression, random forests, or support vector machines using the vectorised training data and the sentiment labels.

# %%
clf = LogisticRegression()
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Evaluate the performance of the classification model on the testing set with the accuracy, precision, recall and F1 score.

# %%
y_pred = clf.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("AUC:", auc(fpr, tpr))
# Out:
# Accuracy: 0.8660287081339713
# AUC: 0.5

# %% [markdown]
# # Excercise 3.1
#
# Remove stopwords, then predict target using CountVectorizer.
#
# use Random Forest classifier

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split

# %% [markdown]
# Removiendo stopwords, puntuación, convirtiendo a minúsculas y stemmatizando

# %%
from nltk.stem.snowball import SnowballStemmer

stop_words = set(stopwords.words("english"))
englishstemmer = SnowballStemmer("english")


def new_preprocess(text):
    text = text.lower()
    text = "".join([word for word in text if word not in string.punctuation])
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stop_words]
    stema = [englishstemmer.stem(w) for w in tokens]  # devuelve palabras stemizadas
    return " ".join(stema)

# %%
from sklearn.metrics import (
    precision_score,
    recall_score,
    f1_score,
    accuracy_score,
    roc_auc_score,
)
from sklearn.preprocessing import StandardScaler


def Random_F(X_train, y_train, X_val, y_val):
    # estandarizar data - entre 0 y 1
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    # Modelo
    modelo = RandomForestClassifier(n_jobs=-1, random_state=42)
    modelo.fit(X_train, y_train)
    y_pred_rf = modelo.predict(X_val)
    auc_ = roc_auc_score(y_val, y_pred_rf)
    return y_pred_rf, accuracy_score(y_val, y_pred_rf), auc_

# %%
X_new = X.apply(new_preprocess)
X_new.head()
# Out:
# 0    go jurong point crazi avail bugi n great world...
# 1                                ok lar joke wif u oni
# 2    free entri 2 wkli comp win fa cup final tkts 2...
# 3                  u dun say earli hor u c alreadi say
# 4            nah dont think goe usf live around though
# Name: text, dtype: object

# %% [markdown]
# Se emplea CountVectorizer

# %%
count_vect = CountVectorizer(stop_words="english")

# %%
CountV = count_vect.fit_transform(X_new).toarray()
CountV.shape
# Out:
# (5572, 7958)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    CountV, y, test_size=0.2, random_state=42
)

# %%
_, accuracy_rf, auc_rf = Random_F(X_train, y_train, X_test, y_test)
print(f"Accuracy: {accuracy_rf}")
print(f"AUC: {auc_rf}")
# Out:
# Accuracy: 0.9748878923766816
# AUC: 0.9060402684563759

# %%
_, accuracy_rf, auc_rf = Random_F(X_train, y_train, X_test, y_test)
print(f"Accuracy: {accuracy_rf}")
print(f"AUC: {auc_rf}")
# Out:
# Accuracy: 0.9748878923766816
# AUC: 0.9060402684563759

# %% [markdown]
# # Excercise 3.2
#
# Predict target using TdidfVectorizer.
#
# use Random Forest classifier

# %%
td_idf = TfidfVectorizer(stop_words="english")

# %%
td_idf_V = td_idf.fit_transform(X_new).toarray()
td_idf_V.shape
# Out:
# (5572, 7958)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    td_idf_V, y, test_size=0.2, random_state=42
)

# %%
_, accuracy_rf, auc_rf = Random_F(X_train, y_train, X_test, y_test)
print(f"Accuracy TD-IDF: {accuracy_rf}")
print(f"AUC TD-IDF: {auc_rf}")
# Out:
# Accuracy TD-IDF: 0.9748878923766816
# AUC TD-IDF: 0.9060402684563759

# %% [markdown]
# # Excercise 3.3
#
# Predict target using CountVectorizer or TfideVectorizer.
#
# choose any classification model and justify why

# %% [markdown]
# Se aplicarán ambos modelos para ver cuál genera mejores resltados

# %% [markdown]
# ### **Modelo XGBoost**

# %%
from xgboost import XGBClassifier


def XGB_(X_train, y_train, X_val, y_val):
    # estandarizar data - entre 0 y 1
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    # Modelo
    xgb = XGBClassifier(eval_metric="mlogloss", n_jobs=-1)
    xgb.fit(X_train, y_train)
    y_pred = xgb.predict(X_val)
    auc_ = roc_auc_score(y_val, y_pred)
    # fpr, tpr, _ = roc_curve(y_val, y_pred)
    return y_pred, accuracy_score(y_val, y_pred), auc_

# %% [markdown]
# ### **Count Vectorizer**

# %%
count_vect = CountVectorizer(stop_words="english")

# %%
CountV = count_vect.fit_transform(X_new).toarray()
CountV.shape
# Out:
# (5572, 7958)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    CountV, y, test_size=0.2, random_state=42
)

# %%
_, accuracy_xgb, auc_xgb = XGB_(X_train, y_train, X_test, y_test)
print(f"Accuracy CV XGB: {accuracy_xgb}")
print(f"AUC CV XGB: {auc_xgb}")
# Out:
# Accuracy CV XGB: 0.8672645739910314
# AUC CV XGB: 0.5033557046979866

# %% [markdown]
# ### **IT-IDF**

# %%
td_idf = TfidfVectorizer(stop_words="english")

# %%
td_idf_V = td_idf.fit_transform(X_new).toarray()
td_idf_V.shape
# Out:
# (5572, 7958)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    td_idf_V, y, test_size=0.2, random_state=42
)

# %%
_, accuracy_xgb, auc_xgb = XGB_(X_train, y_train, X_test, y_test)
print(f"Accuracy IT-IDF XGB: {accuracy_xgb}")
print(f"AUC IT-IDF XGB: {auc_xgb}")
# Out:
# Accuracy IT-IDF XGB: 0.8663677130044843
# AUC IT-IDF XGB: 0.5

# %% [markdown]
# ### **Justificación**
#
# Se empleo el modelo XGBoost debido a que los modelos de ensambles suelen tener bajo sesgo y una varianza más baja que los demás modelos. Adicionalmente, es un modelo de árboles y se quiere observar si es mejor para este problema que un Random Forest.

# %% [markdown]
# # Excercise 3.4
#
# Increase and decrece the parameters values vector_size, window and negative then predict the target.
#
# Plot the different values of the parameters with the performance of the model.
#
# Use a Random Forest classifier and classification model of your choice and justify why.

# %% [markdown]
# ### **Funciones que aplican para todas las siguientes respuestas**

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_new, y, test_size=0.2, random_state=42
)

# %%
def vectorize_new(sentence, model, vs):
    words = sentence.split()
    words_vecs = [model.wv[word] for word in words if word in model.wv]
    if len(words_vecs) == 0:
        return np.zeros(vs)
    words_vecs = np.array(words_vecs)
    return words_vecs.mean(axis=0)

# %%
def cambio_hiperparametros_vs(
    X_train,
    X_test,
    y_train,
    y_test,
    modelo: str,
    vector_size: list = [
        100,
    ],
    window: list = [
        5,
    ],
    negative: list = [
        20,
    ],
):
    accuracy = []
    auc = []
    for vs in vector_size:
        for w in window:
            for n in negative:
                X_train_new, X_test_new = X_train.copy(), X_test.copy()
                sentences = [sentence.split() for sentence in X_train_new]
                model = Word2Vec(
                    sentences,
                    vector_size=vs,
                    window=w,
                    negative=n,
                    min_count=1,
                    workers=4,
                )

                X_train_new = np.array(
                    [vectorize_new(sentence, model, vs) for sentence in X_train_new]
                )
                X_test_new = np.array(
                    [vectorize_new(sentence, model, vs) for sentence in X_test_new]
                )

                if modelo.lower() == "random forest":
                    _, accuracy_, auc_ = Random_F(
                        X_train_new, y_train, X_test_new, y_test
                    )
                elif modelo.lower() == "xgboost":
                    _, accuracy_, auc_ = XGB_(X_train_new, y_train, X_test_new, y_test)
                accuracy.append(accuracy_)
                auc.append(auc_)

                print(
                    f"Finaliza iteración de vector_size: {vs}, window: {w}, negative: {n}"
                )

    return accuracy, auc, vector_size, window, negative

# %% [markdown]
# ### **parameter variation: `vector_size`**

# %% [markdown]
# **Random Forest**

# %%
accuracy_vs, auc_vs, vs, _, _ = cambio_hiperparametros_vs(
    X_train,
    X_test,
    y_train,
    y_test,
    modelo="Random Forest",
    vector_size=list(range(50, 301, 50)),
)
# Out:
# Finaliza iteración de vector_size: 50, window: 5, negative: 20
# Finaliza iteración de vector_size: 100, window: 5, negative: 20
# Finaliza iteración de vector_size: 150, window: 5, negative: 20
# Finaliza iteración de vector_size: 200, window: 5, negative: 20
# Finaliza iteración de vector_size: 250, window: 5, negative: 20
# Finaliza iteración de vector_size: 300, window: 5, negative: 20

# %%
import matplotlib.pyplot as plt

figure = plt.subplots(figsize=(12, 6))
plt.plot(vs, auc_vs, "o-", color="blue")
plt.xlabel("Vector_size")
plt.ylabel("AUC")
plt.title("Variaciacion de AUC por Vector_Size")
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.subplots(figsize=(12, 6))
plt.plot(vs, accuracy_vs, "o-", color="green")
plt.xlabel("Vector_size")
plt.ylabel("Accuracy")
plt.title("Variacion de Accuracy por Vector_Size")
plt.show()

# %% [markdown]
# **XGBoost**

# %%
accuracy_vs, auc_vs, vs, _, _ = cambio_hiperparametros_vs(
    X_train,
    X_test,
    y_train,
    y_test,
    modelo="XGBoost",
    vector_size=list(range(50, 301, 50)),
)
# Out:
# Finaliza iteración de vector_size: 50, window: 5, negative: 20
# Finaliza iteración de vector_size: 100, window: 5, negative: 20
# Finaliza iteración de vector_size: 150, window: 5, negative: 20
# Finaliza iteración de vector_size: 200, window: 5, negative: 20
# Finaliza iteración de vector_size: 250, window: 5, negative: 20
# Finaliza iteración de vector_size: 300, window: 5, negative: 20

# %%
import matplotlib.pyplot as plt

figure = plt.subplots(figsize=(12, 6))
plt.plot(vs, auc_vs, "o-", color="blue")
plt.xlabel("Vector_size")
plt.ylabel("AUC")
plt.title("Variaciacion de AUC por Vector_Size")
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.subplots(figsize=(12, 6))
plt.plot(vs, accuracy_vs, "o-", color="green")
plt.xlabel("Vector_size")
plt.ylabel("Accuracy")
plt.title("Variacion de Accuracy por Vector_Size")
plt.show()

# %% [markdown]
# ### **parameter variation: `window`**

# %% [markdown]
# **Random Forest**

# %%
accuracy_w, auc_w, _, w, _ = cambio_hiperparametros_vs(
    X_train, X_test, y_train, y_test, modelo="Random Forest", window=list(range(5, 11))
)
# Out:
# Finaliza iteración de vector_size: 100, window: 5, negative: 20
# Finaliza iteración de vector_size: 100, window: 6, negative: 20
# Finaliza iteración de vector_size: 100, window: 7, negative: 20
# Finaliza iteración de vector_size: 100, window: 8, negative: 20
# Finaliza iteración de vector_size: 100, window: 9, negative: 20
# Finaliza iteración de vector_size: 100, window: 10, negative: 20

# %%
import matplotlib.pyplot as plt

figure = plt.subplots(figsize=(12, 6))
plt.plot(w, auc_w, "o-", color="blue")
plt.xlabel("Window")
plt.ylabel("AUC")
plt.title("Variaciacion de AUC por Vector_Size")
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.subplots(figsize=(12, 6))
plt.plot(w, accuracy_w, "o-", color="green")
plt.xlabel("Window")
plt.ylabel("Accuracy")
plt.title("Variacion de Accuracy por Vector_Size")
plt.show()

# %% [markdown]
# **XGBoost**

# %%
accuracy_w, auc_w, _, w, _ = cambio_hiperparametros_vs(
    X_train, X_test, y_train, y_test, modelo="XGBoost", window=list(range(5, 11))
)
# Out:
# Finaliza iteración de vector_size: 100, window: 5, negative: 20
# Finaliza iteración de vector_size: 100, window: 6, negative: 20
# Finaliza iteración de vector_size: 100, window: 7, negative: 20
# Finaliza iteración de vector_size: 100, window: 8, negative: 20
# Finaliza iteración de vector_size: 100, window: 9, negative: 20
# Finaliza iteración de vector_size: 100, window: 10, negative: 20

# %%
import matplotlib.pyplot as plt

figure = plt.subplots(figsize=(12, 6))
plt.plot(w, auc_w, "o-", color="blue")
plt.xlabel("Window")
plt.ylabel("AUC")
plt.title("Variaciacion de AUC por Window XGBoost")
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.subplots(figsize=(12, 6))
plt.plot(w, accuracy_w, "o-", color="green")
plt.xlabel("Window")
plt.ylabel("Accuracy")
plt.title("Variacion de Accuracy por Window XGBoost")
plt.show()

# %% [markdown]
# ### **parameter variation: `negative`**

# %% [markdown]
# **Random Forest**

# %%
accuracy_n, auc_n, _, _, n = cambio_hiperparametros_vs(
    X_train,
    X_test,
    y_train,
    y_test,
    modelo="Random Forest",
    negative=list(range(18, 24)),
)
# Out:
# Finaliza iteración de vector_size: 100, window: 5, negative: 18
# Finaliza iteración de vector_size: 100, window: 5, negative: 19
# Finaliza iteración de vector_size: 100, window: 5, negative: 20
# Finaliza iteración de vector_size: 100, window: 5, negative: 21
# Finaliza iteración de vector_size: 100, window: 5, negative: 22
# Finaliza iteración de vector_size: 100, window: 5, negative: 23

# %%
import matplotlib.pyplot as plt

figure = plt.subplots(figsize=(12, 6))
plt.plot(n, auc_n, "o-", color="blue")
plt.xlabel("Negative")
plt.ylabel("AUC")
plt.title("Variaciacion de AUC por Negative Random Forest")
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.subplots(figsize=(12, 6))
plt.plot(n, accuracy_n, "o-", color="green")
plt.xlabel("Window")
plt.ylabel("Accuracy")
plt.title("Variacion de Accuracy por Vector_Size")
plt.show()

# %% [markdown]
# **XGBoost**

# %%
accuracy_n, auc_n, _, _, n = cambio_hiperparametros_vs(
    X_train, X_test, y_train, y_test, modelo="XGBoost", negative=list(range(18, 24))
)
# Out:
# Finaliza iteración de vector_size: 100, window: 5, negative: 18
# Finaliza iteración de vector_size: 100, window: 5, negative: 19
# Finaliza iteración de vector_size: 100, window: 5, negative: 20
# Finaliza iteración de vector_size: 100, window: 5, negative: 21
# Finaliza iteración de vector_size: 100, window: 5, negative: 22
# Finaliza iteración de vector_size: 100, window: 5, negative: 23

# %%
import matplotlib.pyplot as plt

figure = plt.subplots(figsize=(12, 6))
plt.plot(n, auc_n, "o-", color="blue")
plt.xlabel("Negative")
plt.ylabel("AUC")
plt.title("Variaciacion de AUC por Negative XGBoost")
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.subplots(figsize=(12, 6))
plt.plot(n, accuracy_n, "o-", color="green")
plt.xlabel("Negatives")
plt.ylabel("Accuracy")
plt.title("Variacion de Accuracy por Negatives XGBoost")
plt.show()

# %% [markdown]
# ### **Running best parameters `vector_size, window and negative` (All at the same time)**

# %% [markdown]
# **Random Forest**

# %%
accuracy_total, auc_total, sv, w, n = cambio_hiperparametros_vs(
    X_train,
    X_test,
    y_train,
    y_test,
    modelo="Random Forest",
    vector_size=list(range(50, 301, 50)),
    window=list(range(5, 11)),
    negative=list(range(18, 24)),
)
# Out:
# Finaliza iteración de vector_size: 50, window: 5, negative: 18
# Finaliza iteración de vector_size: 50, window: 5, negative: 19
# Finaliza iteración de vector_size: 50, window: 5, negative: 20
# Finaliza iteración de vector_size: 50, window: 5, negative: 21
# Finaliza iteración de vector_size: 50, window: 5, negative: 22
# Finaliza iteración de vector_size: 50, window: 5, negative: 23
# Finaliza iteración de vector_size: 50, window: 6, negative: 18
# Finaliza iteración de vector_size: 50, window: 6, negative: 19
# Finaliza iteración de vector_size: 50, window: 6, negative: 20
# Finaliza iteración de vector_size: 50, window: 6, negative: 21
# Finaliza iteración de vector_size: 50, window: 6, negative: 22
# Finaliza iteración de vector_size: 50, window: 6, negative: 23
# Finaliza iteración de vector_size: 50, window: 7, negative: 18
# Finaliza iteración de vector_size: 50, window: 7, negative: 19
# Finaliza iteración de vector_size: 50, window: 7, negative: 20
# Finaliza iteración de vector_size: 50, window: 7, negative: 21
# Finaliza iteración de vector_size: 50, window: 7, negative: 22
# Finaliza iteración de vector_size: 50, window: 7, negative: 23
# Finaliza iteración de vector_size: 50, window: 8, negative: 18
# Finaliza iteración de vector_size: 50, window: 8, negative: 19
# Finaliza iteración de vector_size: 50, window: 8, negative: 20
# Finaliza iteración de vector_size: 50, window: 8, negative: 21
# Finaliza iteración de vector_size: 50, window: 8, negative: 22
# Finaliza iteración de vector_size: 50, window: 8, negative: 23
# Finaliza iteración de vector_size: 50, window: 9, negative: 18
# Finaliza iteración de vector_size: 50, window: 9, negative: 19
# Finaliza iteración de vector_size: 50, window: 9, negative: 20
# Finaliza iteración de vector_size: 50, window: 9, negative: 21
# Finaliza iteración de vector_size: 50, window: 9, negative: 22
# Finaliza iteración de vector_size: 50, window: 9, negative: 23
# Finaliza iteración de vector_size: 50, window: 10, negative: 18
# Finaliza iteración de vector_size: 50, window: 10, negative: 19
# Finaliza iteración de vector_size: 50, window: 10, negative: 20
# Finaliza iteración de vector_size: 50, window: 10, negative: 21
# Finaliza iteración de vector_size: 50, window: 10, negative: 22
# Finaliza iteración de vector_size: 50, window: 10, negative: 23
# Finaliza iteración de vector_size: 100, window: 5, negative: 18
# Finaliza iteración de vector_size: 100, window: 5, negative: 19
# Finaliza iteración de vector_size: 100, window: 5, negative: 20
# Finaliza iteración de vector_size: 100, window: 5, negative: 21
# Finaliza iteración de vector_size: 100, window: 5, negative: 22
# Finaliza iteración de vector_size: 100, window: 5, negative: 23
# Finaliza iteración de vector_size: 100, window: 6, negative: 18
# Finaliza iteración de vector_size: 100, window: 6, negative: 19
# Finaliza iteración de vector_size: 100, window: 6, negative: 20
# Finaliza iteración de vector_size: 100, window: 6, negative: 21
# Finaliza iteración de vector_size: 100, window: 6, negative: 22
# Finaliza iteración de vector_size: 100, window: 6, negative: 23
# Finaliza iteración de vector_size: 100, window: 7, negative: 18
# Finaliza iteración de vector_size: 100, window: 7, negative: 19
# Finaliza iteración de vector_size: 100, window: 7, negative: 20
# Finaliza iteración de vector_size: 100, window: 7, negative: 21
# Finaliza iteración de vector_size: 100, window: 7, negative: 22
# Finaliza iteración de vector_size: 100, window: 7, negative: 23
# Finaliza iteración de vector_size: 100, window: 8, negative: 18
# Finaliza iteración de vector_size: 100, window: 8, negative: 19
# Finaliza iteración de vector_size: 100, window: 8, negative: 20
# Finaliza iteración de vector_size: 100, window: 8, negative: 21
# Finaliza iteración de vector_size: 100, window: 8, negative: 22
# Finaliza iteración de vector_size: 100, window: 8, negative: 23
# Finaliza iteración de vector_size: 100, window: 9, negative: 18
# Finaliza iteración de vector_size: 100, window: 9, negative: 19
# Finaliza iteración de vector_size: 100, window: 9, negative: 20
# Finaliza iteración de vector_size: 100, window: 9, negative: 21
# Finaliza iteración de vector_size: 100, window: 9, negative: 22
# Finaliza iteración de vector_size: 100, window: 9, negative: 23
# Finaliza iteración de vector_size: 100, window: 10, negative: 18
# Finaliza iteración de vector_size: 100, window: 10, negative: 19
# Finaliza iteración de vector_size: 100, window: 10, negative: 20
# Finaliza iteración de vector_size: 100, window: 10, negative: 21
# Finaliza iteración de vector_size: 100, window: 10, negative: 22
# Finaliza iteración de vector_size: 100, window: 10, negative: 23
# Finaliza iteración de vector_size: 150, window: 5, negative: 18
# Finaliza iteración de vector_size: 150, window: 5, negative: 19
# Finaliza iteración de vector_size: 150, window: 5, negative: 20
# Finaliza iteración de vector_size: 150, window: 5, negative: 21
# Finaliza iteración de vector_size: 150, window: 5, negative: 22
# Finaliza iteración de vector_size: 150, window: 5, negative: 23
# Finaliza iteración de vector_size: 150, window: 6, negative: 18
# Finaliza iteración de vector_size: 150, window: 6, negative: 19
# Finaliza iteración de vector_size: 150, window: 6, negative: 20
# Finaliza iteración de vector_size: 150, window: 6, negative: 21
# Finaliza iteración de vector_size: 150, window: 6, negative: 22
# Finaliza iteración de vector_size: 150, window: 6, negative: 23
# Finaliza iteración de vector_size: 150, window: 7, negative: 18
# Finaliza iteración de vector_size: 150, window: 7, negative: 19
# Finaliza iteración de vector_size: 150, window: 7, negative: 20
# Finaliza iteración de vector_size: 150, window: 7, negative: 21
# Finaliza iteración de vector_size: 150, window: 7, negative: 22
# Finaliza iteración de vector_size: 150, window: 7, negative: 23
# Finaliza iteración de vector_size: 150, window: 8, negative: 18
# Finaliza iteración de vector_size: 150, window: 8, negative: 19
# Finaliza iteración de vector_size: 150, window: 8, negative: 20
# Finaliza iteración de vector_size: 150, window: 8, negative: 21
# Finaliza iteración de vector_size: 150, window: 8, negative: 22
# Finaliza iteración de vector_size: 150, window: 8, negative: 23
# Finaliza iteración de vector_size: 150, window: 9, negative: 18
# Finaliza iteración de vector_size: 150, window: 9, negative: 19
# Finaliza iteración de vector_size: 150, window: 9, negative: 20
# Finaliza iteración de vector_size: 150, window: 9, negative: 21
# Finaliza iteración de vector_size: 150, window: 9, negative: 22
# Finaliza iteración de vector_size: 150, window: 9, negative: 23
# Finaliza iteración de vector_size: 150, window: 10, negative: 18
# Finaliza iteración de vector_size: 150, window: 10, negative: 19
# Finaliza iteración de vector_size: 150, window: 10, negative: 20
# Finaliza iteración de vector_size: 150, window: 10, negative: 21
# Finaliza iteración de vector_size: 150, window: 10, negative: 22
# Finaliza iteración de vector_size: 150, window: 10, negative: 23
# Finaliza iteración de vector_size: 200, window: 5, negative: 18
# Finaliza iteración de vector_size: 200, window: 5, negative: 19
# Finaliza iteración de vector_size: 200, window: 5, negative: 20
# Finaliza iteración de vector_size: 200, window: 5, negative: 21
# Finaliza iteración de vector_size: 200, window: 5, negative: 22
# Finaliza iteración de vector_size: 200, window: 5, negative: 23
# Finaliza iteración de vector_size: 200, window: 6, negative: 18
# Finaliza iteración de vector_size: 200, window: 6, negative: 19
# Finaliza iteración de vector_size: 200, window: 6, negative: 20
# Finaliza iteración de vector_size: 200, window: 6, negative: 21
# Finaliza iteración de vector_size: 200, window: 6, negative: 22
# Finaliza iteración de vector_size: 200, window: 6, negative: 23
# Finaliza iteración de vector_size: 200, window: 7, negative: 18
# Finaliza iteración de vector_size: 200, window: 7, negative: 19
# Finaliza iteración de vector_size: 200, window: 7, negative: 20
# Finaliza iteración de vector_size: 200, window: 7, negative: 21
# Finaliza iteración de vector_size: 200, window: 7, negative: 22
# Finaliza iteración de vector_size: 200, window: 7, negative: 23
# Finaliza iteración de vector_size: 200, window: 8, negative: 18
# Finaliza iteración de vector_size: 200, window: 8, negative: 19
# Finaliza iteración de vector_size: 200, window: 8, negative: 20
# Finaliza iteración de vector_size: 200, window: 8, negative: 21
# Finaliza iteración de vector_size: 200, window: 8, negative: 22
# Finaliza iteración de vector_size: 200, window: 8, negative: 23
# Finaliza iteración de vector_size: 200, window: 9, negative: 18
# Finaliza iteración de vector_size: 200, window: 9, negative: 19
# Finaliza iteración de vector_size: 200, window: 9, negative: 20
# Finaliza iteración de vector_size: 200, window: 9, negative: 21
# Finaliza iteración de vector_size: 200, window: 9, negative: 22
# Finaliza iteración de vector_size: 200, window: 9, negative: 23
# Finaliza iteración de vector_size: 200, window: 10, negative: 18
# Finaliza iteración de vector_size: 200, window: 10, negative: 19
# Finaliza iteración de vector_size: 200, window: 10, negative: 20
# Finaliza iteración de vector_size: 200, window: 10, negative: 21
# Finaliza iteración de vector_size: 200, window: 10, negative: 22
# Finaliza iteración de vector_size: 200, window: 10, negative: 23
# Finaliza iteración de vector_size: 250, window: 5, negative: 18
# Finaliza iteración de vector_size: 250, window: 5, negative: 19
# Finaliza iteración de vector_size: 250, window: 5, negative: 20
# Finaliza iteración de vector_size: 250, window: 5, negative: 21
# Finaliza iteración de vector_size: 250, window: 5, negative: 22
# Finaliza iteración de vector_size: 250, window: 5, negative: 23
# Finaliza iteración de vector_size: 250, window: 6, negative: 18
# Finaliza iteración de vector_size: 250, window: 6, negative: 19
# Finaliza iteración de vector_size: 250, window: 6, negative: 20
# Finaliza iteración de vector_size: 250, window: 6, negative: 21
# Finaliza iteración de vector_size: 250, window: 6, negative: 22
# Finaliza iteración de vector_size: 250, window: 6, negative: 23
# Finaliza iteración de vector_size: 250, window: 7, negative: 18
# Finaliza iteración de vector_size: 250, window: 7, negative: 19
# Finaliza iteración de vector_size: 250, window: 7, negative: 20
# Finaliza iteración de vector_size: 250, window: 7, negative: 21
# Finaliza iteración de vector_size: 250, window: 7, negative: 22
# Finaliza iteración de vector_size: 250, window: 7, negative: 23
# Finaliza iteración de vector_size: 250, window: 8, negative: 18
# Finaliza iteración de vector_size: 250, window: 8, negative: 19
# Finaliza iteración de vector_size: 250, window: 8, negative: 20
# Finaliza iteración de vector_size: 250, window: 8, negative: 21
# Finaliza iteración de vector_size: 250, window: 8, negative: 22
# Finaliza iteración de vector_size: 250, window: 8, negative: 23
# Finaliza iteración de vector_size: 250, window: 9, negative: 18
# Finaliza iteración de vector_size: 250, window: 9, negative: 19
# Finaliza iteración de vector_size: 250, window: 9, negative: 20
# Finaliza iteración de vector_size: 250, window: 9, negative: 21
# Finaliza iteración de vector_size: 250, window: 9, negative: 22
# Finaliza iteración de vector_size: 250, window: 9, negative: 23
# Finaliza iteración de vector_size: 250, window: 10, negative: 18
# Finaliza iteración de vector_size: 250, window: 10, negative: 19
# Finaliza iteración de vector_size: 250, window: 10, negative: 20
# Finaliza iteración de vector_size: 250, window: 10, negative: 21
# Finaliza iteración de vector_size: 250, window: 10, negative: 22
# Finaliza iteración de vector_size: 250, window: 10, negative: 23
# Finaliza iteración de vector_size: 300, window: 5, negative: 18
# Finaliza iteración de vector_size: 300, window: 5, negative: 19
# Finaliza iteración de vector_size: 300, window: 5, negative: 20
# Finaliza iteración de vector_size: 300, window: 5, negative: 21
# Finaliza iteración de vector_size: 300, window: 5, negative: 22
# Finaliza iteración de vector_size: 300, window: 5, negative: 23
# Finaliza iteración de vector_size: 300, window: 6, negative: 18
# Finaliza iteración de vector_size: 300, window: 6, negative: 19
# Finaliza iteración de vector_size: 300, window: 6, negative: 20
# Finaliza iteración de vector_size: 300, window: 6, negative: 21
# Finaliza iteración de vector_size: 300, window: 6, negative: 22
# Finaliza iteración de vector_size: 300, window: 6, negative: 23
# Finaliza iteración de vector_size: 300, window: 7, negative: 18
# Finaliza iteración de vector_size: 300, window: 7, negative: 19
# Finaliza iteración de vector_size: 300, window: 7, negative: 20
# Finaliza iteración de vector_size: 300, window: 7, negative: 21
# Finaliza iteración de vector_size: 300, window: 7, negative: 22
# Finaliza iteración de vector_size: 300, window: 7, negative: 23
# Finaliza iteración de vector_size: 300, window: 8, negative: 18
# Finaliza iteración de vector_size: 300, window: 8, negative: 19
# Finaliza iteración de vector_size: 300, window: 8, negative: 20
# Finaliza iteración de vector_size: 300, window: 8, negative: 21
# Finaliza iteración de vector_size: 300, window: 8, negative: 22
# Finaliza iteración de vector_size: 300, window: 8, negative: 23
# Finaliza iteración de vector_size: 300, window: 9, negative: 18
# Finaliza iteración de vector_size: 300, window: 9, negative: 19
# Finaliza iteración de vector_size: 300, window: 9, negative: 20
# Finaliza iteración de vector_size: 300, window: 9, negative: 21
# Finaliza iteración de vector_size: 300, window: 9, negative: 22
# Finaliza iteración de vector_size: 300, window: 9, negative: 23
# Finaliza iteración de vector_size: 300, window: 10, negative: 18
# Finaliza iteración de vector_size: 300, window: 10, negative: 19
# Finaliza iteración de vector_size: 300, window: 10, negative: 20
# Finaliza iteración de vector_size: 300, window: 10, negative: 21
# Finaliza iteración de vector_size: 300, window: 10, negative: 22
# Finaliza iteración de vector_size: 300, window: 10, negative: 23

# %%
vector_unido = [
    str(v) + "-" + str(wi) + "-" + str(ne) for v in vs for wi in w for ne in n
]
vector_unido[:5]
# Out:
# ['50-5-18', '50-5-19', '50-5-20', '50-5-21', '50-5-22']

# %%
import matplotlib.pyplot as plt

figure = plt.subplots(figsize=(12, 6))
plt.plot(vector_unido, auc_total, "o-", color="blue")
plt.xlabel("Total")
plt.ylabel("AUC")
plt.title("Variaciacion de AUC por Total Random Forest")
plt.show()

# %%
index_best = auc_total.index(max(auc_total))
print(
    f"Se tuvo la mejor mezcla de vector size, window y negative con los siguientes hiperparametros: {vector_unido[index_best]}\nQue genero el siguiente resultado {auc_total[index_best]} "
)
# Out:
# Se tuvo la mejor mezcla de vector size, window y negative con los siguientes hiperparametros: 250-9-23
# Que genero el siguiente resultado 0.8737685327997554

# %%
import matplotlib.pyplot as plt

figure = plt.subplots(figsize=(12, 6))
plt.plot(vector_unido, accuracy_total, "o-", color="green")
plt.xlabel("Window")
plt.ylabel("Accuracy")
plt.title("Variacion de Accuracy por Vector_Size")
plt.show()

# %%
index_best = accuracy_total.index(max(accuracy_total))
print(
    f"Se tuvo la mejor mezcla de vector size, window y negative con los siguientes hiperparametros: {vector_unido[index_best]}\nQue genero el siguiente resultado {accuracy_total[index_best]} "
)
# Out:
# Se tuvo la mejor mezcla de vector size, window y negative con los siguientes hiperparametros: 250-9-23
# Que genero el siguiente resultado 0.9632286995515695

# %% [markdown]
# **XGBoost**

# %%
accuracy_total, auc_total, sv, w, n = cambio_hiperparametros_vs(
    X_train,
    X_test,
    y_train,
    y_test,
    modelo="XGBoost",
    vector_size=list(range(50, 301, 50)),
    window=list(range(5, 11)),
    negative=list(range(18, 24)),
)
# Out:
# Finaliza iteración de vector_size: 50, window: 5, negative: 18
# Finaliza iteración de vector_size: 50, window: 5, negative: 19
# Finaliza iteración de vector_size: 50, window: 5, negative: 20
# Finaliza iteración de vector_size: 50, window: 5, negative: 21
# Finaliza iteración de vector_size: 50, window: 5, negative: 22
# Finaliza iteración de vector_size: 50, window: 5, negative: 23
# Finaliza iteración de vector_size: 50, window: 6, negative: 18
# Finaliza iteración de vector_size: 50, window: 6, negative: 19
# Finaliza iteración de vector_size: 50, window: 6, negative: 20
# Finaliza iteración de vector_size: 50, window: 6, negative: 21
# Finaliza iteración de vector_size: 50, window: 6, negative: 22
# Finaliza iteración de vector_size: 50, window: 6, negative: 23
# Finaliza iteración de vector_size: 50, window: 7, negative: 18
# Finaliza iteración de vector_size: 50, window: 7, negative: 19
# Finaliza iteración de vector_size: 50, window: 7, negative: 20
# Finaliza iteración de vector_size: 50, window: 7, negative: 21
# Finaliza iteración de vector_size: 50, window: 7, negative: 22
# Finaliza iteración de vector_size: 50, window: 7, negative: 23
# Finaliza iteración de vector_size: 50, window: 8, negative: 18
# Finaliza iteración de vector_size: 50, window: 8, negative: 19
# Finaliza iteración de vector_size: 50, window: 8, negative: 20
# Finaliza iteración de vector_size: 50, window: 8, negative: 21
# Finaliza iteración de vector_size: 50, window: 8, negative: 22
# Finaliza iteración de vector_size: 50, window: 8, negative: 23
# Finaliza iteración de vector_size: 50, window: 9, negative: 18
# Finaliza iteración de vector_size: 50, window: 9, negative: 19
# Finaliza iteración de vector_size: 50, window: 9, negative: 20
# Finaliza iteración de vector_size: 50, window: 9, negative: 21
# Finaliza iteración de vector_size: 50, window: 9, negative: 22
# Finaliza iteración de vector_size: 50, window: 9, negative: 23
# Finaliza iteración de vector_size: 50, window: 10, negative: 18
# Finaliza iteración de vector_size: 50, window: 10, negative: 19
# Finaliza iteración de vector_size: 50, window: 10, negative: 20
# Finaliza iteración de vector_size: 50, window: 10, negative: 21
# Finaliza iteración de vector_size: 50, window: 10, negative: 22
# Finaliza iteración de vector_size: 50, window: 10, negative: 23
# Finaliza iteración de vector_size: 100, window: 5, negative: 18
# Finaliza iteración de vector_size: 100, window: 5, negative: 19
# Finaliza iteración de vector_size: 100, window: 5, negative: 20
# Finaliza iteración de vector_size: 100, window: 5, negative: 21
# Finaliza iteración de vector_size: 100, window: 5, negative: 22
# Finaliza iteración de vector_size: 100, window: 5, negative: 23
# Finaliza iteración de vector_size: 100, window: 6, negative: 18
# Finaliza iteración de vector_size: 100, window: 6, negative: 19
# Finaliza iteración de vector_size: 100, window: 6, negative: 20
# Finaliza iteración de vector_size: 100, window: 6, negative: 21
# Finaliza iteración de vector_size: 100, window: 6, negative: 22
# Finaliza iteración de vector_size: 100, window: 6, negative: 23
# Finaliza iteración de vector_size: 100, window: 7, negative: 18
# Finaliza iteración de vector_size: 100, window: 7, negative: 19
# Finaliza iteración de vector_size: 100, window: 7, negative: 20
# Finaliza iteración de vector_size: 100, window: 7, negative: 21
# Finaliza iteración de vector_size: 100, window: 7, negative: 22
# Finaliza iteración de vector_size: 100, window: 7, negative: 23
# Finaliza iteración de vector_size: 100, window: 8, negative: 18
# Finaliza iteración de vector_size: 100, window: 8, negative: 19
# Finaliza iteración de vector_size: 100, window: 8, negative: 20
# Finaliza iteración de vector_size: 100, window: 8, negative: 21
# Finaliza iteración de vector_size: 100, window: 8, negative: 22
# Finaliza iteración de vector_size: 100, window: 8, negative: 23
# Finaliza iteración de vector_size: 100, window: 9, negative: 18
# Finaliza iteración de vector_size: 100, window: 9, negative: 19
# Finaliza iteración de vector_size: 100, window: 9, negative: 20
# Finaliza iteración de vector_size: 100, window: 9, negative: 21
# Finaliza iteración de vector_size: 100, window: 9, negative: 22
# Finaliza iteración de vector_size: 100, window: 9, negative: 23
# Finaliza iteración de vector_size: 100, window: 10, negative: 18
# Finaliza iteración de vector_size: 100, window: 10, negative: 19
# Finaliza iteración de vector_size: 100, window: 10, negative: 20
# Finaliza iteración de vector_size: 100, window: 10, negative: 21
# Finaliza iteración de vector_size: 100, window: 10, negative: 22
# Finaliza iteración de vector_size: 100, window: 10, negative: 23
# Finaliza iteración de vector_size: 150, window: 5, negative: 18
# Finaliza iteración de vector_size: 150, window: 5, negative: 19
# Finaliza iteración de vector_size: 150, window: 5, negative: 20
# Finaliza iteración de vector_size: 150, window: 5, negative: 21
# Finaliza iteración de vector_size: 150, window: 5, negative: 22
# Finaliza iteración de vector_size: 150, window: 5, negative: 23
# Finaliza iteración de vector_size: 150, window: 6, negative: 18
# Finaliza iteración de vector_size: 150, window: 6, negative: 19
# Finaliza iteración de vector_size: 150, window: 6, negative: 20
# Finaliza iteración de vector_size: 150, window: 6, negative: 21
# Finaliza iteración de vector_size: 150, window: 6, negative: 22
# Finaliza iteración de vector_size: 150, window: 6, negative: 23
# Finaliza iteración de vector_size: 150, window: 7, negative: 18
# Finaliza iteración de vector_size: 150, window: 7, negative: 19
# Finaliza iteración de vector_size: 150, window: 7, negative: 20
# Finaliza iteración de vector_size: 150, window: 7, negative: 21
# Finaliza iteración de vector_size: 150, window: 7, negative: 22
# Finaliza iteración de vector_size: 150, window: 7, negative: 23
# Finaliza iteración de vector_size: 150, window: 8, negative: 18
# Finaliza iteración de vector_size: 150, window: 8, negative: 19
# Finaliza iteración de vector_size: 150, window: 8, negative: 20
# Finaliza iteración de vector_size: 150, window: 8, negative: 21
# Finaliza iteración de vector_size: 150, window: 8, negative: 22
# Finaliza iteración de vector_size: 150, window: 8, negative: 23
# Finaliza iteración de vector_size: 150, window: 9, negative: 18
# Finaliza iteración de vector_size: 150, window: 9, negative: 19
# Finaliza iteración de vector_size: 150, window: 9, negative: 20
# Finaliza iteración de vector_size: 150, window: 9, negative: 21
# Finaliza iteración de vector_size: 150, window: 9, negative: 22
# Finaliza iteración de vector_size: 150, window: 9, negative: 23
# Finaliza iteración de vector_size: 150, window: 10, negative: 18
# Finaliza iteración de vector_size: 150, window: 10, negative: 19
# Finaliza iteración de vector_size: 150, window: 10, negative: 20
# Finaliza iteración de vector_size: 150, window: 10, negative: 21
# Finaliza iteración de vector_size: 150, window: 10, negative: 22
# Finaliza iteración de vector_size: 150, window: 10, negative: 23
# Finaliza iteración de vector_size: 200, window: 5, negative: 18
# Finaliza iteración de vector_size: 200, window: 5, negative: 19
# Finaliza iteración de vector_size: 200, window: 5, negative: 20
# Finaliza iteración de vector_size: 200, window: 5, negative: 21
# Finaliza iteración de vector_size: 200, window: 5, negative: 22
# Finaliza iteración de vector_size: 200, window: 5, negative: 23
# Finaliza iteración de vector_size: 200, window: 6, negative: 18
# Finaliza iteración de vector_size: 200, window: 6, negative: 19
# Finaliza iteración de vector_size: 200, window: 6, negative: 20
# Finaliza iteración de vector_size: 200, window: 6, negative: 21
# Finaliza iteración de vector_size: 200, window: 6, negative: 22
# Finaliza iteración de vector_size: 200, window: 6, negative: 23
# Finaliza iteración de vector_size: 200, window: 7, negative: 18
# Finaliza iteración de vector_size: 200, window: 7, negative: 19
# Finaliza iteración de vector_size: 200, window: 7, negative: 20
# Finaliza iteración de vector_size: 200, window: 7, negative: 21
# Finaliza iteración de vector_size: 200, window: 7, negative: 22
# Finaliza iteración de vector_size: 200, window: 7, negative: 23
# Finaliza iteración de vector_size: 200, window: 8, negative: 18
# Finaliza iteración de vector_size: 200, window: 8, negative: 19
# Finaliza iteración de vector_size: 200, window: 8, negative: 20
# Finaliza iteración de vector_size: 200, window: 8, negative: 21
# Finaliza iteración de vector_size: 200, window: 8, negative: 22
# Finaliza iteración de vector_size: 200, window: 8, negative: 23
# Finaliza iteración de vector_size: 200, window: 9, negative: 18
# Finaliza iteración de vector_size: 200, window: 9, negative: 19
# Finaliza iteración de vector_size: 200, window: 9, negative: 20
# Finaliza iteración de vector_size: 200, window: 9, negative: 21
# Finaliza iteración de vector_size: 200, window: 9, negative: 22
# Finaliza iteración de vector_size: 200, window: 9, negative: 23
# Finaliza iteración de vector_size: 200, window: 10, negative: 18
# Finaliza iteración de vector_size: 200, window: 10, negative: 19
# Finaliza iteración de vector_size: 200, window: 10, negative: 20
# Finaliza iteración de vector_size: 200, window: 10, negative: 21
# Finaliza iteración de vector_size: 200, window: 10, negative: 22
# Finaliza iteración de vector_size: 200, window: 10, negative: 23
# Finaliza iteración de vector_size: 250, window: 5, negative: 18
# Finaliza iteración de vector_size: 250, window: 5, negative: 19
# Finaliza iteración de vector_size: 250, window: 5, negative: 20
# Finaliza iteración de vector_size: 250, window: 5, negative: 21
# Finaliza iteración de vector_size: 250, window: 5, negative: 22
# Finaliza iteración de vector_size: 250, window: 5, negative: 23
# Finaliza iteración de vector_size: 250, window: 6, negative: 18
# Finaliza iteración de vector_size: 250, window: 6, negative: 19
# Finaliza iteración de vector_size: 250, window: 6, negative: 20
# Finaliza iteración de vector_size: 250, window: 6, negative: 21
# Finaliza iteración de vector_size: 250, window: 6, negative: 22
# Finaliza iteración de vector_size: 250, window: 6, negative: 23
# Finaliza iteración de vector_size: 250, window: 7, negative: 18
# Finaliza iteración de vector_size: 250, window: 7, negative: 19
# Finaliza iteración de vector_size: 250, window: 7, negative: 20
# Finaliza iteración de vector_size: 250, window: 7, negative: 21
# Finaliza iteración de vector_size: 250, window: 7, negative: 22
# Finaliza iteración de vector_size: 250, window: 7, negative: 23
# Finaliza iteración de vector_size: 250, window: 8, negative: 18
# Finaliza iteración de vector_size: 250, window: 8, negative: 19
# Finaliza iteración de vector_size: 250, window: 8, negative: 20
# Finaliza iteración de vector_size: 250, window: 8, negative: 21
# Finaliza iteración de vector_size: 250, window: 8, negative: 22
# Finaliza iteración de vector_size: 250, window: 8, negative: 23
# Finaliza iteración de vector_size: 250, window: 9, negative: 18
# Finaliza iteración de vector_size: 250, window: 9, negative: 19
# Finaliza iteración de vector_size: 250, window: 9, negative: 20
# Finaliza iteración de vector_size: 250, window: 9, negative: 21
# Finaliza iteración de vector_size: 250, window: 9, negative: 22
# Finaliza iteración de vector_size: 250, window: 9, negative: 23
# Finaliza iteración de vector_size: 250, window: 10, negative: 18
# Finaliza iteración de vector_size: 250, window: 10, negative: 19
# Finaliza iteración de vector_size: 250, window: 10, negative: 20
# Finaliza iteración de vector_size: 250, window: 10, negative: 21
# Finaliza iteración de vector_size: 250, window: 10, negative: 22
# Finaliza iteración de vector_size: 250, window: 10, negative: 23
# Finaliza iteración de vector_size: 300, window: 5, negative: 18
# Finaliza iteración de vector_size: 300, window: 5, negative: 19
# Finaliza iteración de vector_size: 300, window: 5, negative: 20
# Finaliza iteración de vector_size: 300, window: 5, negative: 21
# Finaliza iteración de vector_size: 300, window: 5, negative: 22
# Finaliza iteración de vector_size: 300, window: 5, negative: 23
# Finaliza iteración de vector_size: 300, window: 6, negative: 18
# Finaliza iteración de vector_size: 300, window: 6, negative: 19
# Finaliza iteración de vector_size: 300, window: 6, negative: 20
# Finaliza iteración de vector_size: 300, window: 6, negative: 21
# Finaliza iteración de vector_size: 300, window: 6, negative: 22
# Finaliza iteración de vector_size: 300, window: 6, negative: 23
# Finaliza iteración de vector_size: 300, window: 7, negative: 18
# Finaliza iteración de vector_size: 300, window: 7, negative: 19
# Finaliza iteración de vector_size: 300, window: 7, negative: 20
# Finaliza iteración de vector_size: 300, window: 7, negative: 21
# Finaliza iteración de vector_size: 300, window: 7, negative: 22
# Finaliza iteración de vector_size: 300, window: 7, negative: 23
# Finaliza iteración de vector_size: 300, window: 8, negative: 18
# Finaliza iteración de vector_size: 300, window: 8, negative: 19
# Finaliza iteración de vector_size: 300, window: 8, negative: 20
# Finaliza iteración de vector_size: 300, window: 8, negative: 21
# Finaliza iteración de vector_size: 300, window: 8, negative: 22
# Finaliza iteración de vector_size: 300, window: 8, negative: 23
# Finaliza iteración de vector_size: 300, window: 9, negative: 18
# Finaliza iteración de vector_size: 300, window: 9, negative: 19
# Finaliza iteración de vector_size: 300, window: 9, negative: 20
# Finaliza iteración de vector_size: 300, window: 9, negative: 21
# Finaliza iteración de vector_size: 300, window: 9, negative: 22
# Finaliza iteración de vector_size: 300, window: 9, negative: 23
# Finaliza iteración de vector_size: 300, window: 10, negative: 18
# Finaliza iteración de vector_size: 300, window: 10, negative: 19
# Finaliza iteración de vector_size: 300, window: 10, negative: 20
# Finaliza iteración de vector_size: 300, window: 10, negative: 21
# Finaliza iteración de vector_size: 300, window: 10, negative: 22
# Finaliza iteración de vector_size: 300, window: 10, negative: 23

# %%
vector_unido = [
    str(v) + "-" + str(wi) + "-" + str(ne) for v in vs for wi in w for ne in n
]
vector_unido[:5]
# Out:
# ['50-5-18', '50-5-19', '50-5-20', '50-5-21', '50-5-22']

# %%
import matplotlib.pyplot as plt

figure = plt.subplots(figsize=(12, 6))
plt.plot(vector_unido, auc_total, "o-", color="blue")
plt.xlabel("Total")
plt.ylabel("AUC")
plt.title("Variaciacion de AUC por Total XGBoost")
plt.show()

# %%
index_best = auc_total.index(max(auc_total))
print(
    f"Se tuvo la mejor mezcla de vector size, window y negative con los siguientes hiperparametros: {vector_unido[index_best]}\nQue genero el siguiente resultado {auc_total[index_best]} "
)
# Out:
# Se tuvo la mejor mezcla de vector size, window y negative con los siguientes hiperparametros: 250-6-19
# Que genero el siguiente resultado 0.9024170800505786

# %%
import matplotlib.pyplot as plt

figure = plt.subplots(figsize=(12, 6))
plt.plot(vector_unido, accuracy_total, "o-", color="green")
plt.xlabel("Window")
plt.ylabel("Accuracy")
plt.title("Variacion de Accuracy por Total XGBoost")
plt.show()

# %%
index_best = accuracy_total.index(max(accuracy_total))
print(
    f"Se tuvo la mejor mezcla de vector size, window y negative con los siguientes hiperparametros: {vector_unido[index_best]}\nQue genero el siguiente resultado {accuracy_total[index_best]} "
)
# Out:
# Se tuvo la mejor mezcla de vector size, window y negative con los siguientes hiperparametros: 250-6-19
# Que genero el siguiente resultado 0.968609865470852

# %% [markdown]
# # Conclusiones
#
# Se muestra que los dos modelos fueron buenos en poder realizar la tarea solicitada. Se aclara que para los embeddings generados por Word2Vec el manejo de los hiper parametros es esencial para poder generar una solución óptima.
#
# Adicional se menciona que la mejor solución se encontró con Word2Vec en el algoritmo XGBoost.
